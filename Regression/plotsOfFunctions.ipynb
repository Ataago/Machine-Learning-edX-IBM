# %% [markdown]
# # <center>Demonstration of Various Functions</center>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Linear Function
#
# #### $$ y = mx + c $$

# %%
x = np.arange(-5, 5, 0.1)
y = 2 * x + 3
y_noise = 2 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()

# %% [markdown]
# ## Non Linear Functions
# ### Quadratic Function
# #### $$ y = ax^2 + bx + c $$

# %%
y = 3 * (x**2) + 3 * x + 4
y_noise = 5 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()

# %% [markdown]
# ### Cubic Equation
# #### $$ y = ax^3 + bx^2 + cx + d $$

# %%
y = 1 * (x**3) + 2 * (x**2) + 3 * x + 3
y_noise = 10 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()

# %% [markdown]
# ### Exponential Function
# #### $$ y = a + bc^x $$

# %%
y = 2 + 3 * (2**x)
y_noise = 5 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()

# %% [markdown]
# ### Logarithmic Function
# #### $$ y = Log(x) $$

# %%
y = np.log(x)
y_noise = 0.2 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Sigmoidal/Logistic
# #### $$ y = a + \frac{b}{1 + c^{x - d}} $$

# %%
y = 1 - 1 / (1 + np.power(4, x - 1))
y_noise = 0.1 * np.random.randn(len(x))
y_data = y + y_noise

plt.scatter(x, y_data, c='r')
plt.plot(x, y, c='b')
plt.show()
